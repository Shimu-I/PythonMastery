# %% [markdown]
# # Chapter 5: Debugging

# %% [markdown]
# ## Raising Exception

# %%
raise Exception('This is the error message')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raise Exception('This is the error message')
#
# Exception: This is the error message

# %% [markdown]
# boxPrint.py

# %%
def box_print(symbol, width, height):
  if len(symbol) != 1:
    raise Exception('Symbol must be a single character string.')
  if width <= 2:
    raise Exception('With mush be greater than 2.')
  if height <= 2:
    raise Exception('Height must be greater than 2.')
  print(symbol * width)
  for i in range(height - 2):
    print(symbol + (' ' * (width - 2)) + symbol)
  print(symbol * width)

try:
  box_print('*', 4, 4)
  box_print('0', 20, 5)
  box_print('x', 1, 3)
  box_print('ZZ', 3, 3)
except Exception as err:
  print('An exception happened: ' + str(err))
try:
  box_print('ZZ', 3, 3)
except Exception as err:
  print('An exception happened: '+ str(err))
# Out:
# ****
# *  *
# *  *
# ****
# 00000000000000000000
# 0                  0
# 0                  0
# 0                  0
# 00000000000000000000
# An exception happened: With mush be greater than 2.
# An exception happened: Symbol must be a single character string.

# %% [markdown]
# ## Assertions

# %%
ages = [26, 57, 92, 54, 22, 15, 17, 80, 47, 73]
ages.sort()
print(ages)
assert ages[1] <= ages[-1]
# Out:
# [15, 17, 22, 26, 47, 54, 57, 73, 80, 92]

# %%
ages = [26, 57, 92, 54, 22, 15, 17, 80, 47, 73]
ages.reverse()
print(ages)
assert ages[1] <= ages[-1]
# Out:
# [73, 47, 80, 17, 15, 22, 54, 92, 57, 26]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 ages.reverse()
#       3 print(ages)
# ----> 4 assert ages[1] <= ages[-1]
#
# AssertionError:

# %% [markdown]
# ## Logging

# %% [markdown]
# factorialLog.py

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
logging.debug('Start of program')

def factorial(n):
  logging.debug('Start of factorial(' + str(n) + ')')
  total = 1
  for i in range( n + 1):
    total *= i
    logging.debug('i is ' + str(i) + ', total is ' + str(total))
  logging.debug('End of factorial(' + str(n) + ')')
  return total

print(factorial(5))
logging.debug('End of program')
# Out:
# 2026-03-14 17:22:05,764 - DEBUG - Start of program
# 2026-03-14 17:22:05,765 - DEBUG - Start of factorial(5)
# 2026-03-14 17:22:05,766 - DEBUG - i is 0, total is 0
# 2026-03-14 17:22:05,767 - DEBUG - i is 1, total is 0
# 2026-03-14 17:22:05,767 - DEBUG - i is 2, total is 0
# 2026-03-14 17:22:05,768 - DEBUG - i is 3, total is 0
# 2026-03-14 17:22:05,768 - DEBUG - i is 4, total is 0
# 2026-03-14 17:22:05,769 - DEBUG - i is 5, total is 0
# 2026-03-14 17:22:05,770 - DEBUG - End of factorial(5)
# 2026-03-14 17:22:05,770 - DEBUG - End of program
# 0

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
logging.debug('Start of program')

def factorial(n):
  logging.debug('Start of factorial(' + str(n) + ')')
  total = 1
  for i in range(1, n + 1):
    total *= i
    logging.debug('i is ' + str(i) + ', total is ' + str(total))
  logging.debug('End of factorial(' + str(n) + ')')
  return total

print(factorial(5))
logging.debug('End of program')
# Out:
# 2026-03-14 17:20:32,962 - DEBUG - Start of program
# 2026-03-14 17:20:32,964 - DEBUG - Start of factorial(5)
# 2026-03-14 17:20:32,964 - DEBUG - i is 1, total is 1
# 2026-03-14 17:20:32,965 - DEBUG - i is 2, total is 2
# 2026-03-14 17:20:32,966 - DEBUG - i is 3, total is 6
# 2026-03-14 17:20:32,966 - DEBUG - i is 4, total is 24
# 2026-03-14 17:20:32,967 - DEBUG - i is 5, total is 120
# 2026-03-14 17:20:32,968 - DEBUG - End of factorial(5)
# 2026-03-14 17:20:32,968 - DEBUG - End of program
# 120

# %%
import logging
logging.basicConfig(filename='myProgramLog.txt', level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s', force=True)
logging.debug('Start of program')

def factorial(n):
  logging.debug('Start of factorial(' + str(n) + ')')
  total = 1
  for i in range(1, n + 1):
    total *= i
    logging.debug('i is ' + str(i) + ', total is ' + str(total))
  logging.debug('End of factorial(' + str(n) + ')')
  return total

print(factorial(5))
logging.debug('End of program')
# Out:
# 120

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format=' %(asctime)s - %(levelname)s - %(message)s')

logging.debug('Some minor code and debugging details.')
logging.info('An event happened.')
logging.warning('Someting could go wrong.')
logging.error('An error has occured.')
logging.critical('The program is unable to recover and will now terminated!')

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format=' %(asctime)s - %(levelname)s - %(message)s')

logging.critical('Critical error! Critical error!')
logging.disable(logging.CRITICAL)
logging.critical('Critical error! Critical error!')
logging.error('Error! Error!')

# %% [markdown]
# buggyAddingProgram.py
# <br>
# ![image.png](attachment:image.png)

# %%
print('Enter the first number to add:')
first = input()
print('Enter the second number to add:')
second = input()
print('Enter the third number to add:')
third = input()
print('The sum is ' + first + second + third)
# Out:
# Enter the first number to add:
# Enter the second number to add:
# Enter the third number to add:
# The sum is 123

# %% [markdown]
# coinFlip.py

# %%
import random
heads = 0
for i in range(1, 1001):
  if random.randint(0, 1) == 1:
    heads = heads + 1
  if i == 500:
    print('Halfway done!')
print('Heads came up ' + str(heads) + ' times.')
# Out:
# Halfway done!
# Heads came up 512 times.

# %% [markdown]
# # Practice Program: Debugging Coin Toss

# %%
import random
guess = ''
while guess not in('heads', 'tails'):
  print('Guess the coin toss! Enter heads or tails:')
  guess = input()
toss = random.randint(0, 1) # 0 tails 1 heads
if toss == guess:
  print('You got it!')
else:
  print('Nope! Guess again!')
  guess = input()
  if toss == guess:
    print('You got it!')
  else:
    print('Nope. You are really bad at this game.')
# Out:
# Guess the coin toss! Enter heads or tails:

# %% [markdown]
# fixed the problem and debugged successfully

# %%
import random
guess = ''
while guess not in('heads', 'tails'):
  print('Guess the coin toss! Enter heads or tails:')
  guess = input()
toss_num = random.randint(0, 1) # 0 tails 1 heads
toss = 'tails' if toss_num == 0 else 'heads'
if toss == guess:
  print('You got it!')
else:
  print('Nope! Guess again!')
  guess = input()
  if toss == guess:
    print('You got it!')
  else:
    print('Nope. You are really bad at this game.')
# Out:
# Guess the coin toss! Enter heads or tails:
# Nope! Guess again!
# You got it!
