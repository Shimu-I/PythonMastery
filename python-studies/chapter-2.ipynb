# %%
spam = True
spam
# Out:
# True

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
False = 2 + 2
# Out:
#   Cell In[3], line 1
#     False = 2 + 2
#     ^
# SyntaxError: cannot assign to False

# %% [markdown]
# # Try some operator

# %%
42 == 42
# Out:
# True

# %%
44 == 99
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 != 2
# Out:
# False

# %% [markdown]
# # Example with == and !=

# %%
'hello' == 'hello'
# Out:
# True

# %%
'hello' == 'Hello'
# Out:
# False

# %%
'dog' != 'cat'
# Out:
# True

# %%
True == True
# Out:
# True

# %%
True != False
# Out:
# True

# %%
42 == 42.0
# Out:
# True

# %%
42 == '42'
# Out:
# False

# %% [markdown]
# # Example with < , > , <=, >=

# %%
42 < 100
# Out:
# True

# %%
42 > 100
# Out:
# False

# %%
42 < 42
# Out:
# False

# %%
eggs = 42
eggs <= 42
# Out:
# True

# %%
my_age = 29
my_age >= 10
# Out:
# True

# %% [markdown]
# # Example of and operator

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# # Example of or operator

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# # Example or NOT operator

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# # Example of Comparison and Boolean operators

# %%
(4 < 5) and (5 < 6)
# Out:
# True

# %%
(4 < 5) and (9 < 6)
# Out:
# False

# %%
(1 == 2) or (2 == 2)
# Out:
# True

# %%
spam = 4
2 + 2 == spam and not 2 + 2 == (spam + 1) and 2 * 2 == 2 + 2

# %% [markdown]
# # Bock of code example

# %%
username = 'Mary'
password = 'swordfish'
if username == 'Mary':
  print('Hello, Mary')
  if password == 'swordfish':
    print('Access granted.')
  else:
    print('Wrong password.')
# Out:
# Hello, Mary
# Access granted.
