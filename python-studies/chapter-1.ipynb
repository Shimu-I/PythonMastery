# %%
25 // 8
# Out:
# 3

# %%
25 / 8
# Out:
# 3.125

# %%
14 % 4
# Out:
# 2

# %%
print('hello')
# Out:
# hello

# %%
2 + 2
# Out:
# 4

# %%
'42' + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 '42' + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('Hello, world!')
# Out:
# Hello, world!
